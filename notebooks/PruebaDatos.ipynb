# %%
# %run Datos.ipynb

# %%
muestreoMes = Datos()
muestreoMes.filtrar_mes_dia([["month", "==", "'aug'"], ["day", "==", "'mon'"]])
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0  0.00
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0  0.00
# 64   2  2   aug  mon  91.1  103.2  638.8   5.8  23.1  31   3.1   0.0  0.00
# 94   8  6   aug  mon  91.1  103.2  638.8   5.8  23.4  22   2.7   0.0  0.00
# 120  3  4   aug  mon  91.5  145.4  608.2  10.7  10.3  74   2.2   0.0  0.00
# 121  3  4   aug  mon  91.5  145.4  608.2  10.7  17.1  43   5.4   0.0  0.00
# 260  2  4   aug  mon  93.6   97.9  542.0  14.4  28.3  32   4.0   0.0  8.85
# 376  8  6   aug  mon  92.1  207.0  672.6   8.2  21.1  54   2.2   0.0  0.00
# 427  2  4   aug  mon  92.1  207.0  672.6   8.2  27.9  33   2.2   0.0  2.35
# 436  8  6   aug  mon  92.1  207.0  672.6   8.2  26.8  35   1.3   0.0  0.54
# 441  8  6   aug  mon  92.1  207.0  672.6   8.2  25.5  29   1.8   0.0  1.23
# ...

# %%
muestreoMes = Datos()
muestreoMes.filtrarViento([["month", "==", "'aug'"], ["day", "==", "'mon'"]])
# Out:
#      X  Y month  day  wind
# 6    8  6   aug  mon   3.1
# 64   2  2   aug  mon   3.1
# 121  3  4   aug  mon   5.4
# 260  2  4   aug  mon   4.0
# 452  7  4   aug  mon   4.0
# 495  6  6   aug  mon   2.2
# 496  4  5   aug  mon   3.1

# %%
data = Datos()
data.diagramaDispersion()
